# %% [markdown]
# Finding Missing Value Data

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Student2.csv")
df = pd.DataFrame(data)
df
# Out:
#    S No. Student Name   Age   Hindi   English   Maths   Geography  History  \
# 0      1         Paras  21.0    32.0        80    90.0       90.0       78
# 1      2      Mahendra  20.0    85.0        12    65.0       80.0       91
# 2      3       Simaran   NaN    91.0        65    23.0        NaN       45
# 3      4          Sonu  23.0    71.0        45    45.0       60.0       33
# 4      5         Dipak  19.0     NaN        32    85.0       50.0       48
# 5      6         Rana   18.0    73.0        30    39.0       40.0        7
# 6      7         Sonam  17.0    25.0        40    48.0       26.0       15
# 7      8       Shubham  20.0    81.0        78    76.0       56.0       65
# 8      9         Engla  24.0    88.0        32     1.0       48.0       35
# 9     10          Juhi   NaN    50.0        85     NaN       32.0       38
#
#    Marks_Total  Maximum  Minimum  Count    AVG  %TAGE Result Grade  Result1
# ...

# %%
df.isnull().sum()
# Out:
# S No.             0
# Student Name      0
# Age               2
# Hindi             1
# English           0
# Maths             1
# Geography         1
# History           0
# Marks_Total       1
# Maximum           0
# Minimum           1
# Count             1
# AVG               0
# %TAGE             0
# Result            1
# Grade             0
# Result1          10
# dtype: int64

# %%
df.isna().any()
# Out:
# S No.            False
# Student Name     False
# Age               True
# Hindi             True
# English          False
# Maths             True
# Geography         True
# History          False
# Marks_Total       True
# Maximum          False
# Minimum           True
# Count             True
# AVG              False
# %TAGE            False
# Result            True
# Grade            False
# Result1           True
# dtype: bool

# %%
df.head(5)
# Out:
#    S No. Student Name   Age   Hindi   English   Maths   Geography  History  \
# 0      1         Paras  21.0    32.0        80    90.0       90.0       78
# 1      2      Mahendra  20.0    85.0        12    65.0       80.0       91
# 2      3       Simaran   NaN    91.0        65    23.0        NaN       45
# 3      4          Sonu  23.0    71.0        45    45.0       60.0       33
# 4      5         Dipak  19.0     NaN        32    85.0       50.0       48
#
#    Marks_Total  Maximum  Minimum  Count    AVG  %TAGE Result Grade  Result1
# 0        370.0       90     32.0     5.0  74.0   74.0   Fail     A      NaN
# 1        333.0       91     12.0     5.0  66.6   66.6   Fail     A      NaN
# 2        294.0       91     23.0     NaN  58.8   58.8   Fail     B      NaN
# 3        254.0       71     33.0     5.0  50.8   50.8   Pass     C      NaN
# 4          NaN       85     32.0     5.0  60.0   60.0    NaN     B      NaN

# %%
df.dropna(thresh=5) #thresh is use for drop where mininum null in Rows
# Out:
#    S No. Student Name   Age   Hindi   English   Maths   Geography  History  \
# 0      1         Paras  21.0    32.0        80    90.0       90.0       78
# 1      2      Mahendra  20.0    85.0        12    65.0       80.0       91
# 2      3       Simaran   NaN    91.0        65    23.0        NaN       45
# 3      4          Sonu  23.0    71.0        45    45.0       60.0       33
# 4      5         Dipak  19.0     NaN        32    85.0       50.0       48
# 5      6         Rana   18.0    73.0        30    39.0       40.0        7
# 6      7         Sonam  17.0    25.0        40    48.0       26.0       15
# 7      8       Shubham  20.0    81.0        78    76.0       56.0       65
# 8      9         Engla  24.0    88.0        32     1.0       48.0       35
# 9     10          Juhi   NaN    50.0        85     NaN       32.0       38
#
#    Marks_Total  Maximum  Minimum  Count    AVG  %TAGE Result Grade  Result1
# ...

# %%
df.fillna(0)
# Out:
#    S No. Student Name   Age   Hindi   English   Maths   Geography  History  \
# 0      1         Paras  21.0    32.0        80    90.0       90.0       78
# 1      2      Mahendra  20.0    85.0        12    65.0       80.0       91
# 2      3       Simaran   0.0    91.0        65    23.0        0.0       45
# 3      4          Sonu  23.0    71.0        45    45.0       60.0       33
# 4      5         Dipak  19.0     0.0        32    85.0       50.0       48
# 5      6         Rana   18.0    73.0        30    39.0       40.0        7
# 6      7         Sonam  17.0    25.0        40    48.0       26.0       15
# 7      8       Shubham  20.0    81.0        78    76.0       56.0       65
# 8      9         Engla  24.0    88.0        32     1.0       48.0       35
# 9     10          Juhi   0.0    50.0        85     0.0       32.0       38
#
#    Marks_Total  Maximum  Minimum  Count    AVG  %TAGE Result Grade  Result1
# ...

# %%
values ={'Age':25,'Maths ':91,'Geography':99}
df.fillna(value=values)
# Out:
#    S No. Student Name   Age   Hindi   English   Maths   Geography  History  \
# 0      1         Paras  21.0    32.0        80    90.0       90.0       78
# 1      2      Mahendra  20.0    85.0        12    65.0       80.0       91
# 2      3       Simaran   NaN    91.0        65    23.0       99.0       45
# 3      4          Sonu  23.0    71.0        45    45.0       60.0       33
# 4      5         Dipak  19.0     NaN        32    85.0       50.0       48
# 5      6         Rana   18.0    73.0        30    39.0       40.0        7
# 6      7         Sonam  17.0    25.0        40    48.0       26.0       15
# 7      8       Shubham  20.0    81.0        78    76.0       56.0       65
# 8      9         Engla  24.0    88.0        32     1.0       48.0       35
# 9     10          Juhi   NaN    50.0        85    91.0       32.0       38
#
#    Marks_Total  Maximum  Minimum  Count    AVG  %TAGE Result Grade  Result1
# ...
