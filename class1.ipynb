# %% [markdown]
# Dataframe

# %%
import pandas as pd

# %%
data = {
    'Name':["Sushil","Sanku","Himanshu","Nilesh","Sonu"],
    'Age':[20,22,19,23,17],
    'City':["Bhopal","Indore","Delhi","Balaghat",""],
    'Salary':[55000,45000,23000,75000,8000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Name  Age      City  Salary
# 0    Sushil   20    Bhopal   55000
# 1     Sanku   22    Indore   45000
# 2  Himanshu   19     Delhi   23000
# 3    Nilesh   23  Balaghat   75000
# 4      Sonu   17              8000

# %%
df[["Age","City"]]
# Out:
#    Age      City
# 0   20    Bhopal
# 1   22    Indore
# 2   19     Delhi
# 3   23  Balaghat
# 4   17

# %%
df["M.Number"] =[8349257120,7828795338,7697449908,7770803097,7509217463] # for Add Column
df
# Out:
#        Name  Age      City  Salary    M.Number
# 0    Sushil   20    Bhopal   55000  8349257120
# 1     Sanku   22    Indore   45000  7828795338
# 2  Himanshu   19     Delhi   23000  7697449908
# 3    Nilesh   23  Balaghat   75000  7770803097
# 4      Sonu   17              8000  7509217463

# %%
df.drop("M.Number",axis=1) # for Delete Column
# Out:
#        Name  Age      City  Salary
# 0    Sushil   20    Bhopal   55000
# 1     Sanku   22    Indore   45000
# 2  Himanshu   19     Delhi   23000
# 3    Nilesh   23  Balaghat   75000
# 4      Sonu   17              8000

# %%
df.loc[0]
# Out:
# Name            Sushil
# Age                 20
# City            Bhopal
# Salary           55000
# M.Number    8349257120
# Name: 0, dtype: object

# %%
df.loc[[0,3]]
# Out:
#      Name  Age      City  Salary    M.Number
# 0  Sushil   20    Bhopal   55000  8349257120
# 3  Nilesh   23  Balaghat   75000  7770803097

# %%
df.iloc[4]
# Out:
# Name              Sonu
# Age                 17
# City
# Salary            8000
# M.Number    7509217463
# Name: 4, dtype: object

# %% [markdown]
# Select Subset of Rows and Column

# %%
df
# Out:
#        Name  Age      City  Salary    M.Number
# 0    Sushil   20    Bhopal   55000  8349257120
# 1     Sanku   22    Indore   45000  7828795338
# 2  Himanshu   19     Delhi   23000  7697449908
# 3    Nilesh   23  Balaghat   75000  7770803097
# 4      Sonu   17              8000  7509217463

# %%
df.loc[[1,2]][["City","Salary"]]
# Out:
#      City  Salary
# 1  Indore   45000
# 2   Delhi   23000

# %%
df.loc[[2,3]][["Name",'Age']]
# Out:
#        Name  Age
# 2  Himanshu   19
# 3    Nilesh   23

# %% [markdown]
# Condionsl Selection

# %%
df[df[("Age")]>20] #condition selection
# Out:
#      Name  Age      City  Salary    M.Number
# 1   Sanku   22    Indore   45000  7828795338
# 3  Nilesh   23  Balaghat   75000  7770803097

# %%
df[(df["Salary"]>50000) & (df["City"]=="Balaghat")]
# Out:
#      Name  Age      City  Salary    M.Number
# 3  Nilesh   23  Balaghat   75000  7770803097
